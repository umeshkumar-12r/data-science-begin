# %%
from numpy.dtypes import StringDType
import numpy as np

# %%
arr1 = np.array([1,object(),3.4], dtype=StringDType())

# %%
arr1
# Out:
# array(['1', '<object object at 0x000001E263E75360>', '3.4'],
#       dtype=StringDType())

# %%
arr2 = np.empty(3,dtype = StringDType())

# %%
arr2
# Out:
# array(['', '', ''], dtype=StringDType())

# %%
dt = StringDType(na)
