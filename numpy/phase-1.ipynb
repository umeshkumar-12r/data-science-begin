# %% [markdown]
# ## numbpy learn

# %%
import numpy as np

# %%
arr_id = np.array([1,2,34,6,7])
print(arr_id)
arr_2d =  np.array([[46,45,5],[4,68,96]])
print(arr_2d)
# Out:
# [ 1  2 34  6  7]
# [[46 45  5]
#  [ 4 68 96]]
