# %%
import numpy as np

# %%
marks = np.array([[85, 78, 92],
 [70, 88, 80],
 [90, 95, 85]])

# %%
print(marks[1])
# Out:
# [70 88 80]

# %%
print(marks[:,1])
# Out:
# [78 88 95]

# %%
print(marks.max())
# Out:
# 95

# %%
print(marks.shape)
print(marks.flatten())
# Out:
# (3, 3)
# [85 78 92 70 88 80 90 95 85]
