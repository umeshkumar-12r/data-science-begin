# %% [markdown]
# # DAY 4

# %%
import numpy as np

# %%
marks = np.array([[78,45,79],[88,99,81],[38,89,92]])
print(marks)
# Out:
# [[78 45 79]
#  [88 99 81]
#  [38 89 92]]

# %%
morethan85 = marks > 85
print(marks[morethan85])
# Out:
# [88 99 89 92]

# %%
count = np.sum(marks > 80)
print(count)
# Out:
# 6

# %%
lowermarks = marks.copy()
lowerthan70 = lowermarks <70
lowermarks[lowerthan70] = 50
print(lowermarks)
# Out:
# [[78 50 79]
#  [88 99 81]
#  [50 89 92]]
