# %%
import pandas as pd
import numpy as np

data = {
    "name": ["Umesh", "Prince", "Vikas", "Rohit", "Aman", "Neha"],
    "math": [85, np.nan, 92, 70, 88, 95],
    "english": [80, 75, 90, 85,np.nan, 93],
    "hindi": [82, 79, 88, np.nan, 84, 91]
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#      name  math  english  hindi
# 0   Umesh    85       80     82
# 1  Prince    78       75     79
# 2   Vikas    92       90     88
# 3   Rohit    70       65     60
# 4    Aman    88       85     84

# %%
df.head(3)
# Out:
#      name  math  english  hindi
# 0   Umesh    85       80     82
# 1  Prince    78       75     79
# 2   Vikas    92       90     88

# %%
df.tail()
# Out:
#      name  math  english  hindi
# 1  Prince    78       75     79
# 2   Vikas    92       90     88
# 3   Rohit    70       65     60
# 4    Aman    88       85     84
# 5    Neha    95       93     91

# %%
df.tail(2)
# Out:
#    name  math  english  hindi
# 4  Aman    88       85     84
# 5  Neha    95       93     91

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     6 non-null      str
#  1   math     6 non-null      int64
#  2   english  6 non-null      int64
#  3   hindi    6 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 353.0 bytes

# %%
df.describe()
# Out:
#             math    english      hindi
# count   6.000000   6.000000   6.000000
# mean   84.666667  81.333333  80.666667
# std     9.287985  10.327956  10.984838
# min    70.000000  65.000000  60.000000
# 25%    79.750000  76.250000  79.750000
# 50%    86.500000  82.500000  83.000000
# 75%    91.000000  88.750000  87.000000
# max    95.000000  93.000000  91.000000

# %%
df["math"].value_counts()
# Out:
# math
# 85    1
# 78    1
# 92    1
# 70    1
# 88    1
# 95    1
# Name: count, dtype: int64

# %%
df["name"].unique()
# Out:
# <ArrowStringArray>
# ['Umesh', 'Prince', 'Vikas', 'Rohit', 'Aman', 'Neha']
# Length: 6, dtype: str

# %%
df.dropna()
# Out:
#     name  math  english  hindi
# 0  Umesh  85.0     80.0   82.0
# 2  Vikas  92.0     90.0   88.0
# 5   Neha  95.0     93.0   91.0

# %%
df.isna()
# Out:
#     name   math  english  hindi
# 0  False  False    False  False
# 1  False   True    False  False
# 2  False  False    False  False
# 3  False  False    False   True
# 4  False  False     True  False
# 5  False  False    False  False

# %%
df.fillna(3)
# Out:
#      name  math  english  hindi
# 0   Umesh  85.0     80.0   82.0
# 1  Prince   3.0     75.0   79.0
# 2   Vikas  92.0     90.0   88.0
# 3   Rohit  70.0     85.0    3.0
# 4    Aman  88.0      3.0   84.0
# 5    Neha  95.0     93.0   91.0

# %%
import pandas as pd

data = {
    "name": ["Umesh", "Prince", "Vikas", "Rohit", "Aman", "Neha"],
    "math": [85, 78, 92, 70, 88, 95],
    "english": [80, 75, 90, 65, 85, 93]
}

df = pd.DataFrame(data)

# %%
df["total"] = df["math"] + df["english"]

# %%
df
# Out:
#      name  math  english  total
# 0   Umesh    85       80    165
# 1  Prince    78       75    153
# 2   Vikas    92       90    182
# 3   Rohit    70       65    135
# 4    Aman    88       85    173
# 5    Neha    95       93    188

# %%
df["result"] = df["total"].apply(lambda x: "pass" if x >= 100 else "fail")

# %%
df
# Out:
#      name  math  english  total result grade
# 0   Umesh    85       80    165   pass     b
# 1  Prince    78       75    153   pass     b
# 2   Vikas    92       90    182   pass     a
# 3   Rohit    70       65    135   pass     c
# 4    Aman    88       85    173   pass     a
# 5    Neha    95       93    188   pass     a

# %%
 df.corr(["math"],["english"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.corr(["math"],["english"])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df
# Out:
#      name  math  english  total result grade
# 0   Umesh    85       80    165   fail     b
# 1  Prince    78       75    153   fail     b
# 2   Vikas    92       90    182   pass     a
# 3   Rohit    70       65    135   fail     c
# 4    Aman    88       85    173   pass     a
# 5    Neha    95       93    188   pass     a
