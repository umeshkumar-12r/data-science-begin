# %%
import pandas as pd

# %%
data = {
    "name":["umesh","prashant","dubey","prince"],
    "math":[25,20,25,22],
    "english":[12,25,13,14]
}
data1 = pd.DataFrame(data)

# %%
data1.iloc[0:2,1:3]
# Out:
#    math  english
# 0    25       12
# 1    20       25

# %%
data1.loc[0:2,["math","english"]]
# Out:
#    math  english
# 0    25       12
# 1    20       25
# 2    25       13
